# %% [markdown]
# # word2vecの高速化

# %% [markdown]
# コーパスが大規模のものとなった場合、入力層の計算はone-hot表現の場合、とてつもないメモリが必要となってしまう。<br>
# &rarr; Embeddingレイヤの導入

# %%
# Embeddingレイヤ
import numpy as np

class Embedding :
    def __init__(self, W) :
        self.params = [W]
        self.grads = [np.zeros_like(W)]
        self.idx = None
        
    def forward(self, idx) :
        W, = self.params
        self.idx = idx
        out = W[idx]
        return out
    
    def backward(self, dout) :
        dW, = self.grads
        dW[...] = 0
        for i, word_id in enumerate(self.idx) :
            dW[word_id] += dout[i]
            # np.add.at(dW, self.idx, dout)
        return None

# %% [markdown]
# 中間層以降の計算も多くの計算が必要となり、Softmaxmレイヤに関わる箇所でも、コーパスが大規模になるにつれて計算量が増加することが問題となる。<br>
# &rarr; Nagative Samplingという損失関数の導入(計算量を一定に抑える)

# %%
# EmbeddingDotレイヤの実装
class EmbeddingDot :
    def __init__(self, W) :
        self.embed = Embedding(W)
        self.params = self.embed.params
        sekf.grads = self.embed.grads
        self.cache = None
        
    def forward(self, h, idx) :
        target_W = self.embed.forward(idx)
        out = np.sum(target_W * h, axis=1)
        
        self.cache = (h, target_W)
        return out
    
    def backward(self, dout) :
        h, target_W = self.cache
        dout = dout.reshape(dout.shape[0],1)
        
        dtarget_W = dout * h
        self.embed.backward(dtarget_W)
        df = dout * target_W
        return dh

# %%
# Nagative Samplingの実装
import sys
sys.path.append('./samplecode')
from ch04.negative_sampling_layer import UnigramSampler
from common.layers import SigmoidWithLoss

class NegativeSamplingLoss :
    def __init__(sellf, W, corpus, power=0.75, sample_size=5) :
        self.sample_size = sample_size
        self.sampler = UnigramSampler(corpus, power, sample_size)
        self.loss_layers = [SigmoidWithLoss() for _ in range(sample_size+1)]
        self.embed_dot_layers = [EmbeddingDot(W) for _ in range(sample_size+1)]
        
        self.params, self.grads = [], []
        for layer in self.embed_dot_layers :
            self.params += layer.params
            self.grads += layer.grads
            
    def forward(self, h, target) :
        batch_size = target.shape[0]
        negative_sample = self.sampler.get_negative_sample(target)
        
        score = self.embed_dot_layers[0].forward(h, target)
        correct_label = np.ones(batch_size, dtype=np.int32)
        loss = self.loss_layers[0].forward(score, correct_label)
        
        negative_label = np.zeros(batch_size, dtype=np.int32)
        for i in range(self.sample_size) :
            negative_target = negative_sample[:, i]
            score = self.embed_dot_layers[1+i].forward(h, negative_target)
            loss += self.loss_layers[1+i].forward(score, negative_label)
            
        return loss
    
    def backward(self, dout=1) :
        dh = 0
        for l0, l1 in zip(self.loss_layers, self.embed_dot_layers) :
            dscore = l0.backward(dout)
            dh += l1.backward(dscore)
            
        return dh

# %%
# CBOWモデルの実装
import sys
sys.path.append('./samplecode')
import numpy as np
from common.layers import Embedding
from ch04.negative_sampling_layer import NegativeSamplingLoss

class CBOW :
    def __init__(self, vocab_size, hidden_size, window_size, corpus) :
        V, H = vocab_size, hidden_size
        
        # 重みの初期化
        W_in = 0.01 * np.random.randn(V, H).astype('f')
        W_out = 0.01 * np.random.randn(V, H).astype('f')
        
        # レイヤの生成
        self.in_layers = []
        for i in range(2*window_size) :
            layer = Embedding(W_in)
            self.in_layers.append(layer)
        self.ns_loss = NegativeSamplingLoss(W_out, corpus, power=0.75, sample_size=5)
        
        # すべての重みと勾配を配列にまとめる
        layers = self.in_layers + [self.ns_loss]
        self.params, self.grads = [], []
        for layer in layers :
            self.params += layer.params
            self.grads += layer.grads
            
        # メンバ変数に単語の分散表現を設定
        self.word_vecs = W_in
        
    def forward(self, contexts, target) :
        h = 0
        for i, layer in enumerate(self.in_layers) :
            h += layer.forward(contexts[:, i])
        h *= 1 / len(self.in_layers)
        loss = self.ns_loss.forward(h, target)
        
    def backward(self, dout=1) :
        dout = self.ns_loss.backward(dout)
        dout *= 1 / len(self.in_layers)
        for layer in self.in_layers :
            layer.backward(dout)
        return None

# %%
# CBOWモデルの学習コード(実行にとても時間がかかる)

import sys
sys.path.append('./samplecode')
import numpy as np
from common import config
# GPUで実行する場合は下記を使う(cupyが必要)
# config.GPU = True
import pickle
from common.trainer import Trainer
from common.optimizer import Adam
from ch04.cbow import CBOW
from common.util import create_contexts_target, to_cpu, to_gpu
from dataset import ptb

# ハイパーパラメータの設定
window_size = 5
hidden_size = 100
batch_size = 100
max_epoch = 10

# データの読み込み
corpus, word_to_id, id_to_word = ptb.load_data('train')
vocab_size = len(word_to_id)

contexts, target = create_contexts_target(corpus, window_size)
if config.GPU :
    contexts, target = to_gpu(contexts), to_gpu(target)
    
# モデルの作成
model = CBOW(vocab_size, hidden_size, window_size, corpus)
optimizer = Adam()
trainer = Trainer(model, optimizer)

# 学習開始
trainer.fit(contexts, target, max_epoch, batch_size)
trainer.plot()

# 後ほど利用できるように、必要なデータを保存
word_vecs = model.word_vecs
if config.GPU :
    word_vecs = to_cpu(word_vecs)
params = {}
params['word_vecs'] = word_vecs.astype(np.float16)
params['word_to_id'] = word_to_id
params['id_to_word'] = id_to_word
pkl_file = 'cbow_params.pkl'
with open(pkl_file, 'wb') as f :
    pickle.dump(params, f, -1)
# Out:
# | epoch 1 |  iter 1 / 9295 | time 0[s] | loss 4.16
# | epoch 1 |  iter 21 / 9295 | time 1[s] | loss 4.16
# | epoch 1 |  iter 41 / 9295 | time 3[s] | loss 4.15
# | epoch 1 |  iter 61 / 9295 | time 4[s] | loss 4.12
# | epoch 1 |  iter 81 / 9295 | time 6[s] | loss 4.05
# | epoch 1 |  iter 101 / 9295 | time 8[s] | loss 3.92
# | epoch 1 |  iter 121 / 9295 | time 10[s] | loss 3.78
# | epoch 1 |  iter 141 / 9295 | time 11[s] | loss 3.63
# | epoch 1 |  iter 161 / 9295 | time 13[s] | loss 3.49
# | epoch 1 |  iter 181 / 9295 | time 15[s] | loss 3.37
# | epoch 1 |  iter 201 / 9295 | time 17[s] | loss 3.25
# | epoch 1 |  iter 221 / 9295 | time 18[s] | loss 3.15
# | epoch 1 |  iter 1921 / 9295 | time 157[s] | loss 2.50
# | epoch 1 |  iter 1941 / 9295 | time 159[s] | loss 2.49
# | epoch 1 |  iter 1961 / 9295 | time 160[s] | loss 2.48
# | epoch 1 |  iter 1981 / 9295 | time 162[s] | loss 2.47
# | epoch 1 |  iter 2001 / 9295 | time 163[s] | loss 2.49
# | epoch 1 |  iter 2021 / 9295 | time 165[s] | loss 2.46
# | epoch 1 |  iter 2041 / 9295 | time 167[s] | loss 2.49
# | epoch 1 |  iter 2061 / 9295 | time 168[s] | loss 2.48
# | epoch 1 |  iter 2081 / 9295 | time 170[s] | loss 2.52
# | epoch 1 |  iter 2101 / 9295 | time 171[s] | loss 2.47
# | epoch 1 |  iter 2121 / 9295 | time 173[s] | loss 2.48
# | epoch 1 |  iter 2141 / 9295 | time 174[s] | loss 2.48
# | epoch 1 |  iter 2161 / 9295 | time 176[s] | loss 2.46
# | epoch 1 |  iter 2181 / 9295 | time 177[s] | loss 2.46
# | epoch 1 |  iter 2201 / 9295 | time 180[s] | loss 2.45
# | epoch 1 |  iter 2221 / 9295 | time 182[s] | loss 2.52
# | epoch 1 |  iter 2241 / 9295 | time 184[s] | loss 2.48
# | epoch 1 |  iter 2261 / 9295 | time 186[s] | loss 2.45
# | epoch 1 |  iter 2281 / 9295 | time 187[s] | loss 2.47
# | epoch 1 |  iter 2301 / 9295 | time 189[s] | loss 2.49
# | epoch 1 |  iter 2321 / 9295 | time 191[s] | loss 2.50
# | epoch 1 |  iter 2341 / 9295 | time 192[s] | loss 2.46
# | epoch 1 |  iter 2361 / 9295 | time 194[s] | loss 2.49
# | epoch 1 |  iter 2381 / 9295 | time 196[s] | loss 2.47
# | epoch 1 |  iter 2401 / 9295 | time 197[s] | loss 2.47
# | epoch 1 |  iter 2421 / 9295 | time 199[s] | loss 2.50
# | epoch 1 |  iter 2441 / 9295 | time 201[s] | loss 2.48
# | epoch 1 |  iter 2461 / 9295 | time 202[s] | loss 2.48
# | epoch 1 |  iter 2481 / 9295 | time 204[s] | loss 2.42
# | epoch 1 |  iter 2501 / 9295 | time 206[s] | loss 2.48
# | epoch 1 |  iter 2521 / 9295 | time 207[s] | loss 2.47
# | epoch 1 |  iter 2541 / 9295 | time 209[s] | loss 2.49
# | epoch 1 |  iter 2561 / 9295 | time 211[s] | loss 2.48
# | epoch 1 |  iter 2581 / 9295 | time 212[s] | loss 2.49
# | epoch 1 |  iter 2601 / 9295 | time 214[s] | loss 2.47
# | epoch 1 |  iter 2621 / 9295 | time 215[s] | loss 2.46
# | epoch 1 |  iter 2641 / 9295 | time 217[s] | loss 2.46
# | epoch 1 |  iter 2661 / 9295 | time 219[s] | loss 2.49
# | epoch 1 |  iter 2681 / 9295 | time 220[s] | loss 2.48
# | epoch 1 |  iter 2701 / 9295 | time 222[s] | loss 2.47
# | epoch 1 |  iter 2721 / 9295 | time 224[s] | loss 2.45
# | epoch 1 |  iter 2741 / 9295 | time 225[s] | loss 2.47
# | epoch 1 |  iter 2761 / 9295 | time 227[s] | loss 2.44
# | epoch 1 |  iter 2781 / 9295 | time 229[s] | loss 2.48
# | epoch 1 |  iter 2801 / 9295 | time 230[s] | loss 2.42
# | epoch 1 |  iter 2821 / 9295 | time 232[s] | loss 2.43
# | epoch 1 |  iter 2841 / 9295 | time 233[s] | loss 2.47
# | epoch 1 |  iter 2861 / 9295 | time 235[s] | loss 2.44
# | epoch 1 |  iter 2881 / 9295 | time 237[s] | loss 2.45
# | epoch 1 |  iter 2901 / 9295 | time 238[s] | loss 2.42
# | epoch 1 |  iter 2921 / 9295 | time 240[s] | loss 2.45
# | epoch 1 |  iter 2941 / 9295 | time 241[s] | loss 2.44
# | epoch 1 |  iter 2961 / 9295 | time 243[s] | loss 2.44
# | epoch 1 |  iter 2981 / 9295 | time 245[s] | loss 2.43
# | epoch 1 |  iter 3001 / 9295 | time 247[s] | loss 2.47
# | epoch 1 |  iter 3021 / 9295 | time 249[s] | loss 2.46
# | epoch 1 |  iter 3041 / 9295 | time 250[s] | loss 2.44
# | epoch 1 |  iter 3061 / 9295 | time 252[s] | loss 2.47
# | epoch 1 |  iter 3081 / 9295 | time 253[s] | loss 2.43
# | epoch 1 |  iter 3101 / 9295 | time 255[s] | loss 2.44
# | epoch 1 |  iter 3121 / 9295 | time 257[s] | loss 2.46
# | epoch 1 |  iter 3141 / 9295 | time 258[s] | loss 2.47
# | epoch 1 |  iter 3161 / 9295 | time 260[s] | loss 2.46
# | epoch 1 |  iter 3181 / 9295 | time 262[s] | loss 2.44
# | epoch 1 |  iter 3201 / 9295 | time 263[s] | loss 2.45
# | epoch 1 |  iter 3221 / 9295 | time 265[s] | loss 2.44
# | epoch 1 |  iter 3241 / 9295 | time 267[s] | loss 2.49
# | epoch 1 |  iter 3261 / 9295 | time 268[s] | loss 2.43
# | epoch 1 |  iter 3281 / 9295 | time 270[s] | loss 2.44
# | epoch 1 |  iter 3301 / 9295 | time 272[s] | loss 2.45
# | epoch 1 |  iter 3321 / 9295 | time 273[s] | loss 2.43
# | epoch 1 |  iter 3341 / 9295 | time 275[s] | loss 2.45
# | epoch 1 |  iter 3361 / 9295 | time 277[s] | loss 2.42
# | epoch 1 |  iter 3381 / 9295 | time 278[s] | loss 2.46
# | epoch 1 |  iter 3401 / 9295 | time 280[s] | loss 2.43
# | epoch 1 |  iter 3421 / 9295 | time 281[s] | loss 2.43
# | epoch 1 |  iter 3441 / 9295 | time 283[s] | loss 2.43
# | epoch 1 |  iter 3461 / 9295 | time 285[s] | loss 2.42
# | epoch 1 |  iter 3481 / 9295 | time 286[s] | loss 2.45
# | epoch 1 |  iter 3501 / 9295 | time 288[s] | loss 2.41
# | epoch 1 |  iter 3521 / 9295 | time 290[s] | loss 2.43
# | epoch 1 |  iter 3541 / 9295 | time 292[s] | loss 2.41
# | epoch 1 |  iter 3561 / 9295 | time 293[s] | loss 2.42
# | epoch 1 |  iter 7721 / 9295 | time 651[s] | loss 2.26
# | epoch 1 |  iter 7741 / 9295 | time 653[s] | loss 2.26
# | epoch 1 |  iter 7761 / 9295 | time 654[s] | loss 2.25
# | epoch 1 |  iter 7781 / 9295 | time 656[s] | loss 2.28
# | epoch 1 |  iter 7801 / 9295 | time 658[s] | loss 2.27
# | epoch 1 |  iter 7821 / 9295 | time 659[s] | loss 2.26
# | epoch 1 |  iter 7841 / 9295 | time 661[s] | loss 2.25
# | epoch 1 |  iter 7861 / 9295 | time 662[s] | loss 2.25
# | epoch 1 |  iter 7881 / 9295 | time 664[s] | loss 2.26
# | epoch 1 |  iter 7901 / 9295 | time 665[s] | loss 2.28
# | epoch 1 |  iter 7921 / 9295 | time 667[s] | loss 2.27
# | epoch 1 |  iter 7941 / 9295 | time 668[s] | loss 2.26
# | epoch 1 |  iter 7961 / 9295 | time 670[s] | loss 2.24
# | epoch 1 |  iter 7981 / 9295 | time 671[s] | loss 2.26
# | epoch 1 |  iter 8001 / 9295 | time 673[s] | loss 2.23
# | epoch 1 |  iter 8021 / 9295 | time 675[s] | loss 2.26
# | epoch 1 |  iter 8041 / 9295 | time 676[s] | loss 2.26
# | epoch 1 |  iter 8061 / 9295 | time 678[s] | loss 2.27
# | epoch 1 |  iter 8081 / 9295 | time 679[s] | loss 2.27
# | epoch 1 |  iter 8101 / 9295 | time 681[s] | loss 2.26
# | epoch 1 |  iter 8121 / 9295 | time 682[s] | loss 2.23
# | epoch 1 |  iter 8141 / 9295 | time 684[s] | loss 2.22
# | epoch 1 |  iter 8161 / 9295 | time 685[s] | loss 2.24
# | epoch 1 |  iter 8181 / 9295 | time 687[s] | loss 2.25
# | epoch 1 |  iter 8201 / 9295 | time 688[s] | loss 2.27
# | epoch 1 |  iter 8221 / 9295 | time 690[s] | loss 2.23
# | epoch 1 |  iter 8241 / 9295 | time 691[s] | loss 2.25
# | epoch 1 |  iter 8261 / 9295 | time 693[s] | loss 2.26
# | epoch 1 |  iter 8281 / 9295 | time 695[s] | loss 2.26
# | epoch 1 |  iter 8301 / 9295 | time 696[s] | loss 2.22
# | epoch 1 |  iter 8321 / 9295 | time 698[s] | loss 2.24
# | epoch 1 |  iter 8341 / 9295 | time 699[s] | loss 2.24
# | epoch 1 |  iter 8361 / 9295 | time 701[s] | loss 2.26
# | epoch 1 |  iter 8381 / 9295 | time 702[s] | loss 2.25
# | epoch 1 |  iter 8401 / 9295 | time 704[s] | loss 2.23
# | epoch 1 |  iter 8421 / 9295 | time 706[s] | loss 2.22
# | epoch 1 |  iter 8441 / 9295 | time 707[s] | loss 2.19
# | epoch 1 |  iter 8461 / 9295 | time 709[s] | loss 2.27
# | epoch 1 |  iter 8481 / 9295 | time 710[s] | loss 2.25
# | epoch 1 |  iter 8501 / 9295 | time 712[s] | loss 2.23
# | epoch 1 |  iter 8521 / 9295 | time 714[s] | loss 2.22
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-dbcf3458af14> in <module>()
#      34
#      35 # 学習開始
# ---> 36 trainer.fit(contexts, target, max_epoch, batch_size)
#      37 trainer.plot()
#      38
#
# ~/Desktop/ゼミ_修士/勉強会_安藤研/materials/samplecode/common/trainer.py in fit(self, x, t, max_epoch, batch_size, max_grad, eval_interval)
#      39                 loss = model.forward(batch_x, batch_t)
#      40                 model.backward()
# ---> 41                 params, grads = remove_duplicate(model.params, model.grads)  # 共有された重みを1つに集約
#      42                 if max_grad is not None:
#      43                     clip_grads(grads, max_grad)
#
# ~/Desktop/ゼミ_修士/勉強会_安藤研/materials/samplecode/common/trainer.py in remove_duplicate(params, grads)
#     153                 # 重みを共有する場合
#     154                 if params[i] is params[j]:
# --> 155                     grads[i] += grads[j]  # 勾配の加算
#     156                     find_flg = True
#     157                     params.pop(j)
#
# KeyboardInterrupt:

# %%
import sys
sys.path.append('./samplecode')
from common.util import most_similar
import pickle

pkl_file = 'cbow_params.pkl'

with open(pkl_file, 'rb') as f :
    params = pickle.load(f)
    word_vecs = params['word_vecs']
    word_to_id = params['word_to_id']
    id_to_word = params['id_to_word']
    
querys = ['you', 'year', 'car', 'toyota']
for query in querys :
    most_similar(query, word_to_id,id_to_word, word_vecs, top=5)
# Out:
# [query] you
#  we: 0.6103515625
#  someone: 0.59130859375
#  i: 0.55419921875
#  something: 0.48974609375
#  anyone: 0.47314453125
#
# [query] year
#  month: 0.71875
#  week: 0.65234375
#  spring: 0.62744140625
#  summer: 0.6259765625
#  decade: 0.603515625
#
# [query] car
#  luxury: 0.497314453125
#  arabia: 0.47802734375
#  auto: 0.47119140625
#  disk-drive: 0.450927734375
#  travel: 0.4091796875
#
# [query] toyota
#  ford: 0.55078125
#  instrumentation: 0.509765625
#  mazda: 0.49365234375
#  bethlehem: 0.47509765625
#  nissan: 0.474853515625

# %%
from common.util import analogy

analogy('man', 'king', 'woman', word_to_id, id_to_word, word_vecs, top=5)
analogy('take', 'took', 'go', word_to_id, id_to_word, word_vecs, top=5)
analogy('car', 'cars', 'child', word_to_id, id_to_word, word_vecs, top=5)
analogy('good', 'better', 'bad', word_to_id, id_to_word, word_vecs, top=5)
# Out:
# [analogy] man:king = woman:?
#  she: 4.1796875
#  moody: 4.1328125
#  share: 4.05078125
#  character: 3.966796875
#  chain: 3.912109375
#
# [analogy] take:took = go:?
#  went: 4.55078125
#  points: 4.25
#  began: 4.09375
#  comes: 3.98046875
#  oct.: 3.90625
#
# [analogy] car:cars = child:?
#  children: 5.21875
#  average: 4.7265625
#  yield: 4.20703125
#  cattle: 4.1875
#  priced: 4.1796875
#
# [analogy] good:better = bad:?
#  more: 6.6484375
#  less: 6.0625
#  rather: 5.21875
#  slower: 4.734375
#  greater: 4.671875
